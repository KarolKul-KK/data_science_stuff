# %%
import psycopg2
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-95f405d04364> in <module>
# ----> 1 import psycopg2
#       2 import pandas as pd
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
from platform import python_version

print(python_version())
# Out:
# 3.8.2

# %%
# !pip3 install psycopg2
# Out:
# ...
#   Using cached psycopg2-2.8.6.tar.gz (383 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/pz/fny_hjkj42b858wbzldqw2440000gp/T/pip-install-dbk1pcz2/psycopg2_eeaadad5699745799ca4d2cdd090dae2/setup.py'"'"'; __file__='"'"'/private/var/folders/pz/fny_hjkj42b858wbzldqw2440000gp/T/pip-install-dbk1pcz2/psycopg2_eeaadad5699745799ca4d2cdd090dae2/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/pz/fny_hjkj42b858wbzldqw2440000gp/T/pip-pip-egg-info-nhcar7ku
#          cwd: /private/var/folders/pz/fny_hjkj42b858wbzldqw2440000gp/T/pip-install-dbk1pcz2/psycopg2_eeaadad5699745799ca4d2cdd090dae2/
#     Complete output (23 lines):
#     running egg_info
# ...
